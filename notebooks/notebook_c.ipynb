# %%
x_new = 10
prediction = model['slope'] * x_new + model['intercept']
print("prediction at x =", x_new, "->", prediction)

# %%
print("final prediction:", prediction)

# %%
adjusted_prediction = prediction + weight_total
print("adjusted prediction:", adjusted_prediction)

# %%
predicted_label = names[int(prediction) % len(names)]
sentence = f"{names[0]} and {names[1]} are working with {names[2]} on {names[3]}."
print("predicted label:", predicted_label)
print("sentence:", sentence)

# %%
print(prediction)
