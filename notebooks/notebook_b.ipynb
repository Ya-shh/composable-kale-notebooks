# %%
print("names:", names)

# %%
xs = [d['x'] for d in dataset]
ys = [d['y'] for d in dataset]
n = len(xs)
denom = n * sum(x * x for x in xs) - sum(xs) ** 2
slope = (n * sum(x * y for x, y in zip(xs, ys)) - sum(xs) * sum(ys)) / denom
intercept = (sum(ys) - slope * sum(xs)) / n
print("fitted line -> slope:", slope, "intercept:", intercept)

# %%
model = {"slope": slope, "intercept": intercept}
print("model:", model)

# %%
weight_total = sum(weights)
print("weight_total:", weight_total)
