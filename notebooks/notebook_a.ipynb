# %%
names = ["Eder", "Stefano", "Yash", "kale-GSoC'2026"]
print("names:", names)

# %%
raw_points = [(1, 3), (2, 6), (3, 9), (4, 12)]
print("raw_points:", raw_points)

# %%
dataset = [{"x": x, "y": y} for (x, y) in raw_points]
print("dataset:", dataset)

# %%
weights = [1, 2, 3, 4]
print("weights:", weights)
